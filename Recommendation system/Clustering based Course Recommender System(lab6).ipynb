# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML321ENSkillsNetwork817-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Clustering based Course Recommender System**

# %% [markdown]
# Estimated time needed: **90** minutes

# %% [markdown]
# Previously, we have generated user profile vectors based on course ratings and genres.
#
# A user profile vector may look like a row vector in the following matrix, for example, we can see the Database column for user2 has a value 1 which means user2 is very interesting in courses related to the databases. With the user profile vectors generated, we can also easily compute the similarity among users based on their shared interests.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles.png)

# %% [markdown]
# Furthermore, we could perform clustering algorithms such as K-means or DBSCAN to group users with similar learning interests. For example, in the below user clusters, we have user clusters whom have learned courses related to machine learning, cloud computing, databases, and web development, etc.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles_clustering.png)

# %% [markdown]
# For each user group, we can come up with a list of popular courses. For example, for the machine learning user cluster/learning group, we can count the most frequently enrolled courses, which are very likely to be the most popular and good machine learning courses because they are enrolled by many users who are interested in machine learning.
#
# If we know a user belongs to the machine learning group, we may recommend the most enrolled courses to them and it is very likely the user will be interested in them.

# %% [markdown]
# Next in this lab, you will be implementing some clustering-based recommender system algorithms.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# * Perform k-means clustering on the original user profile feature vectors
# * Apply PCA (Principle Component Analysis ) on user profile feature vectors to reduce dimensions
# * Perform k-means clustering on the PCA transformed main components
# * Generate course recommendations based on other group members' enrollment history

# %% [markdown]
# ----

# %% [markdown]
# ## Prepare and setup lab environment

# %% [markdown]
# First install and import required libraries:

# %%
# !pip install scikit-learn==1.0.2
# !pip install seaborn==0.11.1
# Out:
# Collecting scikit-learn==1.0.2
#   Downloading scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 58.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.14.6 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from scikit-learn==1.0.2) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from scikit-learn==1.0.2) (1.7.3)
# Collecting joblib>=0.11 (from scikit-learn==1.0.2)
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 40.1 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0 (from scikit-learn==1.0.2)
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.20.1
#     Uninstalling scikit-learn-0.20.1:
#       Successfully uninstalled scikit-learn-0.20.1
# Successfully installed joblib-1.3.1 scikit-learn-1.0.2 threadpoolctl-3.1.0
# Collecting seaborn==0.11.1
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from seaborn==0.11.1) (1.21.6)
# Requirement already satisfied: scipy>=1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from seaborn==0.11.1) (1.7.3)
# Requirement already satisfied: pandas>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from seaborn==0.11.1) (1.3.5)
# Requirement already satisfied: matplotlib>=2.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from seaborn==0.11.1) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (8.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas>=0.23->seaborn==0.11.1) (2023.3)
# Requirement already satisfied: typing-extensions in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn==0.11.1) (4.5.0)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.1) (1.16.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.9.0
#     Uninstalling seaborn-0.9.0:
#       Successfully uninstalled seaborn-0.9.0
# Successfully installed seaborn-0.11.1

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
# also set a random state
rs = 123

# %% [markdown]
# ### Load the user profile dataset

# %% [markdown]
# Let's first load the original user profile feature vectors:

# %%
user_profile_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/user_profile.csv"
user_profile_df = pd.read_csv(user_profile_url)
user_profile_df.head()
# Out:
#    user  Database  Python  CloudComputing  DataAnalysis  Containers  \
# 0     2      52.0    14.0             6.0          43.0         3.0
# 1     4      40.0     2.0             4.0          28.0         0.0
# 2     5      24.0     8.0            18.0          24.0         0.0
# 3     7       2.0     0.0             0.0           2.0         0.0
# 4     8       6.0     0.0             0.0           4.0         0.0
#
#    MachineLearning  ComputerVision  DataScience  BigData  Chatbot     R  \
# 0             33.0             0.0         29.0     41.0      2.0  18.0
# 1             14.0             0.0         20.0     24.0      0.0   6.0
# 2             30.0             0.0         22.0     14.0      2.0  14.0
# 3              0.0             0.0          0.0      2.0      0.0   0.0
# 4              0.0             0.0          0.0      6.0      0.0   2.0
#
#    BackendDev  FrontendDev  Blockchain
# 0        34.0          9.0         6.0
# 1         6.0          0.0         2.0
# 2        26.0          4.0         6.0
# 3         0.0          0.0         0.0
# 4         0.0          0.0         0.0

# %%
user_profile_df.shape
# Out:
# (33901, 15)

# %% [markdown]
# we can then list the feature names, they are the user interested topics (course genres):

# %%
feature_names = list(user_profile_df.columns[1:])
feature_names
# Out:
# ['Database',
#  'Python',
#  'CloudComputing',
#  'DataAnalysis',
#  'Containers',
#  'MachineLearning',
#  'ComputerVision',
#  'DataScience',
#  'BigData',
#  'Chatbot',
#  'R',
#  'BackendDev',
#  'FrontendDev',
#  'Blockchain']

# %% [markdown]
# As we can see from the user profile dataset, we have about 33K unique users with interests in areas like ``Database``, ``Python``, ``CloudComputing``, etc. Then, let's check the  summary statistics for each feature.

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  33901.000000  33901.000000    33901.000000  33901.000000
# mean   1.064064e+06      5.518569      3.493791        2.307100      3.624701
# std    4.972578e+05      7.611941      4.227254        3.841858      4.760135
# min    2.000000e+00      0.000000      0.000000        0.000000      0.000000
# 25%    6.813480e+05      0.000000      0.000000        0.000000      0.000000
# 50%    1.043907e+06      3.000000      3.000000        0.000000      3.000000
# 75%    1.451159e+06      9.000000      6.000000        3.000000      6.000000
# max    2.103039e+06     63.000000     18.000000       38.000000     48.000000
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  33901.000000     33901.000000    33901.000000  33901.000000
# mean       0.998938         3.048022        0.001770      5.087343
# std        2.351764         4.624004        0.072846      5.230697
# min        0.000000         0.000000        0.000000      0.000000
# 25%        0.000000         0.000000        0.000000      0.000000
# 50%        0.000000         0.000000        0.000000      3.000000
# 75%        0.000000         3.000000        0.000000      9.000000
# max       15.000000        39.000000        3.000000     32.000000
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  33901.000000  33901.000000  33901.000000  33901.000000  33901.000000
# mean       4.750450      0.462995      1.017433      2.269461      0.315802
# std        7.216228      1.055186      2.342532      4.310752      1.363462
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        2.000000      0.000000      0.000000      0.000000      0.000000
# 75%        6.000000      0.000000      0.000000      3.000000      0.000000
# max       54.000000      6.000000     18.000000     54.000000     15.000000
#
#          Blockchain
# count  33901.000000
# mean       0.986844
# std        1.950585
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000

# %% [markdown]
# The original user profile feature vector is not normalized, which may cause issues when we perform clustering and Principal component analysis (PCA), therefor we standardize the data.

# %%
# Use StandardScaler to make each feature with mean 0, standard deviation 1
scaler = StandardScaler()
user_profile_df[feature_names] = scaler.fit_transform(user_profile_df[feature_names])
print("mean {} and standard deviation{} ".format(user_profile_df[feature_names].mean(),user_profile_df[feature_names].std()))
# Out:
# mean Database          -2.217793e-14
# Python             7.204451e-14
# CloudComputing    -3.443061e-14
# DataAnalysis      -2.543096e-15
# Containers         2.028543e-14
# MachineLearning   -1.199377e-14
# ComputerVision     3.136613e-15
# DataScience        5.723643e-15
# BigData           -4.646660e-15
# Chatbot            1.207204e-14
# R                 -5.597167e-15
# BackendDev        -7.880864e-15
# FrontendDev       -2.312337e-14
# Blockchain         4.286451e-14
# dtype: float64 and standard deviationDatabase           1.000015
# Python             1.000015
# CloudComputing     1.000015
# DataAnalysis       1.000015
# Containers         1.000015
# MachineLearning    1.000015
# ComputerVision     1.000015
# DataScience        1.000015
# BigData            1.000015
# Chatbot            1.000015
# R                  1.000015
# BackendDev         1.000015
# FrontendDev        1.000015
# Blockchain         1.000015
# dtype: float64

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  3.390100e+04  3.390100e+04    3.390100e+04  3.390100e+04
# mean   1.064064e+06 -2.217793e-14  7.204451e-14   -3.443061e-14 -2.543096e-15
# std    4.972578e+05  1.000015e+00  1.000015e+00    1.000015e+00  1.000015e+00
# min    2.000000e+00 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 25%    6.813480e+05 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 50%    1.043907e+06 -3.308757e-01 -1.168130e-01   -6.005256e-01 -1.312380e-01
# 75%    1.451159e+06  4.573712e-01  5.928781e-01    1.803581e-01  4.990056e-01
# max    2.103039e+06  7.551593e+00  3.431642e+00    9.290667e+00  9.322416e+00
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  3.390100e+04     3.390100e+04    3.390100e+04  3.390100e+04
# mean   2.028543e-14    -1.199377e-14    3.136613e-15  5.723643e-15
# std    1.000015e+00     1.000015e+00    1.000015e+00  1.000015e+00
# min   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 25%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 50%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -3.990622e-01
# 75%   -4.247674e-01    -1.038556e-02   -2.429612e-02  7.480294e-01
# max    5.953517e+00     7.775190e+00    4.115884e+01  5.145214e+00
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04
# mean  -4.646660e-15  1.207204e-14 -5.597167e-15 -7.880864e-15 -2.312337e-14
# std    1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00
# min   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 25%   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 50%   -3.811535e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 75%    1.731609e-01 -4.387873e-01 -4.343370e-01  1.694715e-01 -2.316212e-01
# max    6.824934e+00  5.247500e+00  7.249771e+00  1.200053e+01  1.076995e+01
#
#          Blockchain
# count  3.390100e+04
# mean   4.286451e-14
# std    1.000015e+00
# min   -5.059295e-01
# 25%   -5.059295e-01
# 50%   -5.059295e-01
# 75%    5.194189e-01
# max    5.646161e+00

# %% [markdown]
# The normalized user profile features are:

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
features
# Out:
#        Database    Python  CloudComputing  DataAnalysis  Containers  \
# 0      6.106474  2.485388        0.961242      8.272010    0.850889
# 1      4.529980 -0.353377        0.440653      5.120792   -0.424767
# 2      2.427988  1.066006        4.084776      4.280467   -0.424767
# 3     -0.462250 -0.826504       -0.600526     -0.341319   -0.424767
# 4      0.063248 -0.826504       -0.600526      0.078843   -0.424767
# ...         ...       ...             ...           ...         ...
# 33896 -0.330876 -0.116813        0.180358      0.499006   -0.424767
# 33897 -0.724999 -0.826504       -0.079936     -0.761482   -0.424767
# 33898 -0.330876  0.592878        0.961242     -0.761482   -0.424767
# 33899 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
# 33900 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
#
#        MachineLearning  ComputerVision  DataScience   BigData   Chatbot  \
# 0             6.477594       -0.024296     4.571668  5.023412  1.456642
# 1             2.368540       -0.024296     2.851031  2.667576 -0.438787
# 2             5.828796       -0.024296     3.233395  1.281790  1.456642
# 3            -0.659184       -0.024296    -0.972608 -0.381153 -0.438787
# 4            -0.659184       -0.024296    -0.972608  0.173161 -0.438787
# ...                ...             ...          ...       ...       ...
# 33896        -0.659184       -0.024296     0.174484 -0.658311 -0.438787
# 33897        -0.659184       -0.024296    -0.972608 -0.658311 -0.438787
# 33898         2.368540       -0.024296     0.748029 -0.658311 -0.438787
# 33899        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
# 33900        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
#
#               R  BackendDev  FrontendDev  Blockchain
# 0      7.249771    7.360899     6.369323    2.570116
# 1      2.127032    0.865416    -0.231621    0.519419
# 2      5.542191    5.505047     2.702132    2.570116
# 3     -0.434337   -0.526473    -0.231621   -0.505930
# 4      0.419453   -0.526473    -0.231621   -0.505930
# ...         ...         ...          ...         ...
# 33896  2.127032    0.865416    -0.231621    1.032093
# 33897 -0.434337   -0.526473    -0.231621   -0.505930
# 33898  0.846348   -0.526473    -0.231621   -0.505930
# 33899 -0.434337   -0.526473    -0.231621   -0.505930
# 33900 -0.434337   -0.526473    -0.231621   -0.505930
#
# [33901 rows x 14 columns]

# %% [markdown]
# we can also save the user ids for later recommendation tasks:

# %%
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
user_ids
# Out:
#           user
# 0            2
# 1            4
# 2            5
# 3            7
# 4            8
# ...        ...
# 33896  2102054
# 33897  2102356
# 33898  2102680
# 33899  2102983
# 33900  2103039
#
# [33901 rows x 1 columns]

# %% [markdown]
# ### TASK: Perform K-means clustering algorithm on the user profile feature vectors

# %% [markdown]
# With the user profile dataset ready, you need to use the `KMeans` class provided by scikit-learn library to perform clustering on the user profile feature vectors.

# %% [markdown]
# For `KMeans` algorithm, one important hyperparameter is the number of clusters `n_cluster`, and a good way to find the optimized `n_cluster` is using to grid search a list of candidates and find the one with the best or optimized clustering evaluation metrics such as minimal `sum of squared distance`:

# %% [markdown]
# _TODO: grid search the optimized n_cluster for KMeans() model_

# %%
# WRITE YOUR CODE HERE

# Find an optimized number of neighors k from a candidate list such as list_k = list(range(1, 30))
from sklearn.cluster import KMeans


from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

distorsions = []
for k in range(1, 30):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(features)
    distorsions.append(kmeans.inertia_)

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# Create a list that will hold the the sum of square distances for each fitted model. For each k in `n_clusters` make a model by calling `KMeans(n_clusters=k, random_state=rs).fit(features)` ans append `model.inertia_` to the list. Plot square distances against the k values.
#
# </details>

# %% [markdown]
# If you plot the grid search process, you may get a elbow plot like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/clusters_elbow.png)

# %% [markdown]
# From the elbow plot, you should visualy identify the point where the metric starting to be flatten, which indicates the optimized number of clusters.

# %% [markdown]
# Once you have identified the best number of clusters, you can apply `KMeans()` again to generate cluster label for all users.

# %%
cluster_labels = [None] * len(user_ids)

# %% [markdown]
# _TODO: Apply KMeans() on the features with optimized n_cluster parameter after model fitting, you can find output cluster labels in `model.labels_` attribute_

# %%
## WRITE YOUR CODE HERE

## ...
## cluster_labels = model.labels
## ...
model=KMeans(n_clusters=k, random_state=rs).fit(features)
cluster_labels = model.labels_

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# Create  a model by calling `KMeans(n_clusters=k, random_state=rs).fit(features)`. Save the labels by accessing `model.labels`.
#
# </details>

# %% [markdown]
# The cluster labels you generated is a list of integers indicating cluster indices. You may use the following utility method to combine the cluster labels and user ids to a dataframe, so that you know which cluster a user belongs:

# %%
def combine_cluster_labels(user_ids, labels):
    labels_df = pd.DataFrame(labels)
    cluster_df = pd.merge(user_ids, labels_df, left_index=True, right_index=True)
    cluster_df.columns = ['user', 'cluster']
    return cluster_df
deff=combine_cluster_labels(user_ids, cluster_labels)
deff
# Out:
#           user  cluster
# 0            2        6
# 1            4       12
# 2            5       10
# 3            7        1
# 4            8       27
# ...        ...      ...
# 33896  2102054       14
# 33897  2102356        1
# 33898  2102680        3
# 33899  2102983        1
# 33900  2103039        1
#
# [33901 rows x 2 columns]

# %% [markdown]
# Your clustering results may look like the following screenshot:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/cluster_labels.png)

# %% [markdown]
# Now, each user finds its own cluster or we can say we have created many clusters of learning communities. Learners within each community share very similar learning interests.

# %% [markdown]
# ### TASK: Apply PCA on user profile feature vectors to reduce dimensions

# %% [markdown]
# In the previous step, we applied `KMeans` on the original user profile feature vectors which have 14 original features (the course genres).

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
feature_names = list(user_profile_df.columns[1:])

# %%
print(f"There are {len(feature_names)} features for each user profile.")
# Out:
# There are 14 features for each user profile.

# %% [markdown]
# If we plot a covariance matrix of the user profile feature vectors with 14 features, we can observe that some features are actually correlated:

# %%
sns.set_theme(style="white")

# Compute the correlation matrix
corr = features.cov()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


plt.show()

# %% [markdown]
# For example, the feature `MachineLearning` and the feature `DataScience` are correlated. Such covariances among features may indicate that we can apply PCA to find its main components (eigenvectors with max eigenvalues on the covariance matrix).
#
# If we only keep the independent main components, then we can reduce the dimensions of our user profile feature vectors.

# %% [markdown]
# Now let's apply the `PCA()` provided by  `scikit-learn` to find the main components in user profile feature vectors and see if we can reduce its dimensions by only keeping the main components.

# %% [markdown]
# Note that when calling the  `PCA()` class, there is also an import argument called `n_components` which indicates how many components you want to keep in the PCA result. One way to find an optimized `n_components` is to do a grid search on a list of argument candidates (such as `range(1, 15)`) and calculate the ratio of the accumulated variance for each candidate.
#
# If the accumulated variances ratio of a candidate `n_components` is larger than a threshold, e.g., 90%, then we can say the transformed `n_components` could explain about 90% of variances of the original data variance and can be considered as an optimized components size.

# %% [markdown]
# _TODO: Find the optimized `n_components` for PCA_

# %%
# WRITE YOUR CODE HERE

# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
accumulated_variance_ratios = []
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
for k in range(1, 14):
    pca=PCA(n_components=k)
    pca.fit_transform(features)
    accumulated_variance_ratios.append(pca.explained_variance_ratio_.sum())
aculist=[i for i in range(len(accumulated_variance_ratios)) if accumulated_variance_ratios[i] >= 0.9]
min_ratio=min(aculist)
min_ratio
# Out:
# 8

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * For each `n_components` from 1 to 14 you can call `PCA=PCA(n_components=component)`, then you can simply fit it by callsing `pca.fit_transform(features)` where `features = user_profile_df.loc[:, user_profile_df.columns != 'user']`.
# * Then you can find `accumulated_variance_ratios` by applying `sum()` to `pca.explained_variance_ratio_`.
# * Then find the smallest n_components value for which `accumulated_variance_ratios >= 0.9` and return it.
# </details>

# %% [markdown]
# If you visualize your hyperparameter searching process, you may get a trend line like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/pca.png)

# %% [markdown]
# Once you found the optimized `n_component` argument value, you can apply PCA on the user profile feature vectors and reduce the  14 features into  `n_component` features.

# %% [markdown]
# _TODO: Perform PCA to transform original user profile features_

# %%
# WRITE YOUR CODE HERE

# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
# - Merge the user ids and transformed features into a new dataframe
pca=PCA(n_components=8)
components=pca.fit_transform(features)
new_data=pd.DataFrame(data=components)
merged_def=user_ids.merge(new_data,left_index=True, right_index=True)

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * Call PCA class as `pca = PCA(n_components=n_components)`
# * Fit PCA model using predefined `features` variable as only parameter
# * Get the components by calling `pca.fit_transform(features)`
# * Create a `pd.DataFrame(data=components)` and use `pd.merge` to merge it with `user_ids` don't forget to specify `left_index=True, right_index=True` in `merge` function parameters.
#
# </details>

# %% [markdown]
# Your PCA transformed dataframe may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/pca_res.png)

# %% [markdown]
# ### TASK: Perform k-means clustering on the PCA transformed feature vectors

# %% [markdown]
# Now, you have the PCA  components of the original profile vectors. You can perform k-means on them again:

# %% [markdown]
# _TODO: Perform K-means on the PCA transformed features_

# %%
## WRITE YOUR CODE HERE

## - Apply KMeans() on the PCA features
## - Obtain the cluster label lists from model.labels_ attribute
## - Assign each user a cluster label by combining user ids and cluster labels

kmeans = KMeans(n_clusters=12)
kmeans.fit(components)
cluster_labels = kmeans.labels_
cluster_df=user_ids.merge(pd.DataFrame(data=cluster_labels),left_index=True, right_index=True)
cluster_df. columns = ['user'] + ['cluster']
cluster_df
# Out:
#           user  cluster
# 0            2       10
# 1            4        3
# 2            5       10
# 3            7        4
# 4            8        4
# ...        ...      ...
# 33896  2102054       11
# 33897  2102356        4
# 33898  2102680        2
# 33899  2102983        4
# 33900  2103039        4
#
# [33901 rows x 2 columns]

# %% [markdown]
# Your clustering results should have the same format as the k-means on the original dataset:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/cluster_labels.png)

# %% [markdown]
# Great, now all users find their learning interest groups, either based on their original or the PCA transformed user profile features.

# %% [markdown]
# When a user is in a group or a community, it is very likely that the user will be interested in the courses enrolled by other members within the same group.

# %% [markdown]
# ### TASK: Generate course recommendations based on the popular courses in the same cluster

# %% [markdown]
# The Intuition of clustering-based course recommendation is very simple and can be illustrated via the following example:

# %% [markdown]
# Suppose a user has joined a machine learning group (via clustering algorithm). In the group, he/she finds that the top-3 courses enrolled by all other group members are `Machine Learning for Everyone`, `Machine Learning with Python`, `Machine Learning with Scikit-learn`. Since the user has already completed the `Machine Learning for Everyone` earlier, he/she decides to trust the group members' choices and enroll in other two unselected courses `Machine Learning with Python` and `Machine Learning with Scikit-learn`.

# %% [markdown]
# In summary, the clustering-based recommender system first groups all users based on their profiles, and maintains a popular courses list for each group.
#
# For any group member who needs course recommendations, the algorithm recommends the unselected courses from the popular course lists.

# %% [markdown]
# Next, suppose we have a set of test users, and we want to recommend new courses to them using a clustering-based recommender system:

# %%
test_user_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/rs_content_test.csv"
test_users_df = pd.read_csv(test_user_url)[['user', 'item']]
test_users_df.head()
# Out:
#       user      item
# 0  1502801  RP0105EN
# 1  1609720  CNSC02EN
# 2  1347188  CO0301EN
# 3   755067  ML0103EN
# 4   538595  BD0115EN

# %% [markdown]
# The test users dataset has only two columns, the user id and the enrolled course id.

# %% [markdown]
# For each user, let's find its cluster label using the k-means results you have performed in previous steps, assuming it is named `cluster_df`.

# %% [markdown]
# You can assign the cluster label to all test users via merging the clustering labels (`cluster_df`:):

# %%
test_users_labelled = pd.merge(test_users_df, cluster_df, left_on='user', right_on='user')
test_users_labelled
# Out:
#          user      item  cluster
# 0     1502801  RP0105EN        9
# 1     1502801  BD0131EN        9
# 2     1502801  BD0212EN        9
# 3     1502801  BD0115EN        9
# 4     1502801  BD0211EN        9
# ...       ...       ...      ...
# 9397   630511  BD0121EN        9
# 9398   630511  SC0101EN        9
# 9399   630511  BD0111EN        9
# 9400   630511  BD0115EN        9
# 9401   630511  PY0101EN        9
#
# [9402 rows x 3 columns]

# %% [markdown]
# The merged the test dataset may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/test_users_label.png)

# %% [markdown]
# From the above dataframe, we know each user's enrolled courses and its cluster index.

# %% [markdown]
# If we use a `groupby`  and `sum` aggregation, we can get the enrollments count for each course in each group, like the following code snippet:

# %%
courses_cluster = test_users_labelled[['item', 'cluster']]
courses_cluster['count'] = [1] * len(courses_cluster)
courses_cluster.groupby(['cluster','item']).agg(enrollments = ('count','sum')).reset_index()
courses_cluster
# Out:
#           item  cluster  count
# 0     RP0105EN        9      1
# 1     BD0131EN        9      1
# 2     BD0212EN        9      1
# 3     BD0115EN        9      1
# 4     BD0211EN        9      1
# ...        ...      ...    ...
# 9397  BD0121EN        9      1
# 9398  SC0101EN        9      1
# 9399  BD0111EN        9      1
# 9400  BD0115EN        9      1
# 9401  PY0101EN        9      1
#
# [9402 rows x 3 columns]

# %% [markdown]
# _TODO: For each test user, try to recommend any unseen courses based on the popular courses in his/her cluster. You may use an enrollment count threshold (such as larger than 10) to determine if it is a popular course in the cluster_

# %%
## WRITE YOUR CODE HERE

## - For each user, first finds its cluster label

    ## - First get all courses belonging to the same cluster and figure out what are the popular ones (such as course enrollments beyond a threshold like 100)
    
    ## - Get the user's current enrolled courses
    
    ## - Check if there are any courses on the popular course list which are new/unseen to the user. 
    
    ## If yes, make those unseen and popular courses as recommendation results for the user
test_users = test_users_labelled.groupby(['user']).max().reset_index(drop=False)
user_id= test_users['user'].to_list()
popular_courses_by_cluster = {}
j=0
for i in range(13):
    tmp_df = test_users_labelled[test_users_labelled['cluster']==i]
    popular_courses_by_cluster[i] = tmp_df['item'].values[:3]
for i in user_id:
    user_subset=test_users_labelled[test_users_labelled['user'] == i]
    enrolled_courses=user_subset['item']
    cluster=user_subset['cluster'].iloc[0]
    all_courses=test_users_labelled[test_users_labelled['cluster'] == cluster]
    unselected_course_ids = set(popular_courses_by_cluster).difference(set(enrolled_courses))
    print(f'user {i} :{popular_courses_by_cluster[cluster][:3]}')
    j=j+1
print(j)
    
# for index, row in test_users_labelled.iterrows():
#     user = row['user']
#     cluster = row['cluster']
#     print(f'user {user} in cluster {cluster} is recommened 3 courses as {popular_courses_by_cluster[cluster][:3]}')
# for i in user_id:
#     user_subset=test_users_labelled[test_users_labelled['user'] == i]
#     enrolled_courses=user_subset['item']
#     cluster=user_subset['cluster'].iloc[0]
#     all_courses=test_users_labelled[test_users_labelled[test_users_labelled['cluster'] == cluster]
# Out:
# user 37465 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 50348 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 52091 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 70434 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 85625 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 108541 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 109915 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 134697 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 142685 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 149690 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 152320 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 160015 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 161471 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 179356 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 181124 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 182509 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 182847 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 187819 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 189913 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 203388 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 211118 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 220851 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 243266 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 246282 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 246703 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 261571 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 266643 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 271899 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 277197 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 277715 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 284008 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 296101 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 306665 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 314348 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 315714 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 331334 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 331432 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 343800 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 345064 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 348808 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 351320 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 352684 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 354686 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 362955 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 364194 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 371091 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 373076 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 376785 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 390213 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 396776 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 397562 :['LB0107ENv1' 'LB0103ENv1' 'LB0105ENv1']
# user 399457 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 403519 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 403839 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 406451 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 406940 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 408938 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 413286 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 418401 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 419414 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 422079 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 425952 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 426277 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 428501 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 428830 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 430274 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 431224 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 435051 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 435578 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 435858 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 435898 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 440679 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 446388 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 446982 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 447524 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 457527 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 459415 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 461049 :['DS0103EN' 'BC0201EN' 'CO0401EN']
# user 461359 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 462554 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 462755 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 464965 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 471338 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 472908 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 476115 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 476798 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 477953 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 480186 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 481019 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 481658 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 482875 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 483426 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 484628 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 485273 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 486201 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 489692 :['DS0103EN' 'BC0201EN' 'CO0401EN']
# user 491004 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 494226 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 497128 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 497451 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 503032 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 503291 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 506042 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 506202 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 506734 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 510780 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 511765 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 514320 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 515823 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 517197 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 518515 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 518867 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 528259 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 529858 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 531408 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 536821 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 538595 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 539916 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 542255 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 542454 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 543504 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 544738 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 545870 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 547966 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 550887 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 551330 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 552288 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 553969 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 555836 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 556941 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 558382 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 559369 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 560247 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 564038 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 565505 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 569052 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 569284 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 572721 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 573047 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 574414 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 576061 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 576397 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 577001 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 577409 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 578677 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 581446 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 583245 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 584748 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 585227 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 585654 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 587229 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 591984 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 599839 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 600214 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 601371 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 603336 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 603361 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 606214 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 606648 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 606892 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 607310 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 607999 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 608432 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 609057 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 609064 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 613802 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 614638 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 615039 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 616284 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 619829 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 620075 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 620994 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 621285 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 621497 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 621543 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 624248 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 625223 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 625486 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 627837 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 628701 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 629108 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 629189 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 630417 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 630511 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 632294 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 639271 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 641270 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 641998 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 642609 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 643167 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 645459 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 646160 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 646861 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 646951 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 646991 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 647516 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 655195 :['LB0107ENv1' 'LB0103ENv1' 'LB0105ENv1']
# user 660570 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 661906 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 663689 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 666015 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 666135 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 666633 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 666770 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 667110 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 669512 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 671203 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 673206 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 674939 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 676094 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 676097 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 676317 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 679194 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 681552 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 681785 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 682652 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 683043 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 684186 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user
:['TA0105' 'RP0101EN' 'DS0301EN']
# user 1625299 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1626145 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1627236 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1627595 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1628200 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1632349 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1634015 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 1636610 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1637328 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1637560 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1641257 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1642918 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 1643171 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1643210 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 1646441 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1648099 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1649175 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1650969 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1655079 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1656151 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1657304 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1658021 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1658936 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 1660009 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1662401 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1664399 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1665194 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 1667543 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1669680 :['DS0103EN' 'BC0201EN' 'CO0401EN']
# user 1669829 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1672648 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1675314 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1676221 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1676451 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1679018 :['LB0107ENv1' 'LB0103ENv1' 'LB0105ENv1']
# user 1687045 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1688004 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1688159 :['LB0107ENv1' 'LB0103ENv1' 'LB0105ENv1']
# user 1688652 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 1691061 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1691129 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1691612 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1696376 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1697610 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1697791 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1699356 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1699606 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1713082 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1714575 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 1715864 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1717303 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 1717953 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 1718448 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1719220 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1720300 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1730573 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1730632 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1730913 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1735651 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1736248 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1738888 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 1743750 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1744047 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1751031 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 1751931 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1752907 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1758635 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1758996 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1759305 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1764803 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1766896 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1768789 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1770354 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1773079 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1773434 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1776689 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1781984 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1783867 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1784245 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 1788961 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 1799705 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1803286 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1803385 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1803965 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 1804257 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1806207 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1806813 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1808215 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1811287 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1813704 :['TA0105EN' 'DS0103EN' 'ML0101ENv3']
# user 1813726 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1818149 :['DS0103EN' 'BC0201EN' 'CO0401EN']
# user 1819037 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1823144 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1824570 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1828981 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1830259 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1831769 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1831780 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1832099 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1832234 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1832901 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1838639 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1840422 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1840749 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1843006 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1847555 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1855220 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1855847 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1856259 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1858250 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1864236 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1864557 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 1864644 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1866295 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1868084 :['LB0107ENv1' 'LB0103ENv1' 'LB0105ENv1']
# user 1870948 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1871037 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1871214 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 1871627 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1881160 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1882084 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 1884765 :['DS0103EN' 'BC0201EN' 'CO0401EN']
# user 1886079 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1887480 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1888188 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1889420 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1893628 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1897898 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1898770 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 1904245 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1907898 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 1911140 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 1912529 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 1916042 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1916547 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1919394 :['LB0107ENv1' 'LB0103ENv1' 'LB0105ENv1']
# user 1919984 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 1920814 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 1922237 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1929807 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1935753 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1944533 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 1950381 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1953163 :['DS0301EN' 'DJ0101EN' 'DV0101EN']
# user 1955349 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1964245 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 1977334 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 1978886 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 1986311 :['CO0301EN' 'CC0103EN' 'CO0201EN']
# user 2000341 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 2000884 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 2002590 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 2004142 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 2012017 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 2020759 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 2021696 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 2022708 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 2032910 :['TA0105' 'RP0101EN' 'DS0301EN']
# user 2036996 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 2046621 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 2050073 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 2052832 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 2056704 :['DV0151EN' 'PY0101EN' 'RP0101EN']
# user 2056952 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 2057052 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 2061096 :['RP0105EN' 'BD0131EN' 'BD0212EN']
# user 2074313 :['CNSC02EN' 'ML0101ENv3' 'DS0101EN']
# user 2074462 :['CO0101EN' 'BD0101EN' 'BC0201EN']
# user 2082818 :['CC0201EN' 'CC0103EN' 'CC0250EN']
# user 2087663 :['DS0103EN' 'BC0201EN' 'CO0401EN']
# 1000

# %% [markdown]
# <details>
#     <summary>Click here for Hints</summary>
#
# * First of all, create a `user_subset` of  `test_users_labelled` where `test_users_labelled['user'] == user_id`.
# * Get the enrolled courses by  simply accessing `['item']` column of `user_subset`
# * Find its cluster label by accessing `['cluster']` column of `user_subset`. You can just use the first one (`.iloc[0]`) since every value in the column is the same for an individual user.
# * You can find all courses in the same cluster, by simply accessing `['item']` column of a subset of `test_users_labelled` where `test_users_labelled[test_users_labelled['cluster'] == cluster_id]`
# * You can find new/unseen courses to the user by taking a set difference between courses in cluster and enrolled_courses by using `.difference` method (dont forget to convert 2 lists in to sets before calling the method).
# * Use `courses_cluster` data set to find popularity of new/unseen courses and make unseen and popular courses as recommendation results for the user
#
# </details>

# %% [markdown]
# With the recommendation results, you also need to write some analytic code to answer the following two questions:

# %% [markdown]
# - On average, how many new/unseen courses have been recommended to each user?
# - What are the most frequently recommended courses? Return the top-10 commonly recommended courses across all users.

# %% [markdown]
# For example, suppose we have only 3 test users, each user receives the following recommendations:

# %% [markdown]
# - User1: ['course1', 'course2']
# - User2: ['course3', 'course4']
# - User3: ['course3', 'course4', 'course5']

# %% [markdown]
# Then, the average recommended courses per user is $(2 + 2 + 3) / 3 = 2.33$. The top-2 recommended courses are: `course3`: 2 times, and `course4`: 2 times.

# %% [markdown]
# Note that the answers will depend on how you compute the popular courses for each cluster. A lower threshold yields more recommended courses but with smaller confidence so that some test users may receive very long course recommendation lists and feel overwhelmed.
#
# Ideally, we should limit the maximum course recommendations for each user to be less than 20 courses per user.

# %% [markdown]
# ### Explore other clustering algorithms

# %% [markdown]
# As you have learned in previous unsupervised learning course, there are many other clustering algorithms such as `DBSCAN` and `Hierarchical Clustering`. You are encouraged to try them on the user profile feature vectors and compare the results with K-means.

# %% [markdown]
# ### Summary

# %% [markdown]
# Congratulations! In this lab, you have applied clustering algorithms to group users with similar interests and also tried PCA to reduce the dimensions of user feature vectors.
#
# Furthermore, with each user finding its learning interest group, you have also implemented clustering-based course recommender system to make recommendations based on his/her group members' popular courses choices.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo](https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML321ENSkillsNetwork817-2022-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2021-10-25|1.0|Yan|Created the initial version|

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
